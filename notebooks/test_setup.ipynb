# %%
import torch
import cv2
import sklearn
import numpy as np

print("Torch:", torch.__version__)
print("OpenCV:", cv2.__version__)
print("Sklearn:", sklearn.__version__)
# Out:
# Torch: 2.11.0
# OpenCV: 4.13.0
# Sklearn: 1.7.2
